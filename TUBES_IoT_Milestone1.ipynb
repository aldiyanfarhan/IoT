# %% [markdown]
# Nama Anggota
# 1.   Aldiyan Farhan N
# 2.   M Rifqi Wiliatawa

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data
seismic = pd.read_excel(r'C:\KULIAH\IoT\UAS\My Experiment 2022-06-01 20-49-53.xls')
audio = pd.read_excel(r'C:\KULIAH\IoT\UAS\Audio Scope 2022-06-01 20-37-07.xls')

# %%
seismic.head()
# Out:
#    Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0  0.071614                      -0.024450                      -0.066754
# 1  0.091614                      -0.054961                      -0.053359
# 2  0.114753                      -0.054723                      -0.053261
# 3  0.134753                      -0.054662                      -0.053266
# 4  0.154753                      -0.054648                      -0.053242
#
#    Linear Acceleration z (m/s^2)
# 0                       0.004043
# 1                       0.003901
# 2                       0.003899
# 3                       0.003899
# 4                       0.003899

# %%
audio
# Out:
#        Time (ms)  Recording (a.u.)
# 0       0.000000          0.014008
# 1       0.020834          0.019349
# 2       0.041668          0.011017
# 3       0.062502          0.002319
# 4       0.083336         -0.003723
# ...          ...               ...
# 9593  199.861737          0.166967
# 9594  199.882571          0.142460
# 9595  199.903405          0.121220
# 9596  199.924240          0.110599
# 9597  199.945074          0.110508
#
# [9598 rows x 2 columns]

# %%
# PLOT Seismic
seismic[['Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)']].plot()
plt.title("seismic")
# Out:
# Text(0.5, 1.0, 'seismic')

# %%
# PLOT Audio
audio[['Recording (a.u.)']].plot()
plt.title("audio")
# Out:
# Text(0.5, 1.0, 'audio')
